# %%
import pandas as pd
data = pd.read_csv("Book1.csv")

# %%
print(data)
# Out:
#   Ecprience qulification skill  age hired
# 0       yes      masters    py   30   yes
# 1        no    bachelors  java   28   yes
# 2       yes    bachelors    py   31    no
# 3       yes      masters   c++   45   yes
# 4        no      masters    py   25    no

# %%
def find_s_algorithm(data):

    attributes = data.iloc[:, :-1].values
    target = data.iloc[:, -1].values

    hypothesis = None  

    for i in range(len(target)):

        if target[i] == "Yes":  
            hypothesis = attributes[i].copy()
            break

  
    if hypothesis is None:
        print("No positive examples found in dataset.")
        return None

    for i in range(len(target)):

        if target[i] == "Yes":

            for j in range(len(hypothesis)):

                if hypothesis[j] != attributes[i][j]:
                    hypothesis[j] = '?'  

    return hypothesis


final_hypothesis = find_s_algorithm(data)

print("Most Specific Hypothesis:", final_hypothesis)
# Out:
# No positive examples found in dataset.
# Most Specific Hypothesis: None
